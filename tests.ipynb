# %%
# %matplotlib inline

import cPickle
import numpy as np
from theano import tensor, function
from pylab import imshow
from pylab import rcParams

from agnez.weight import grid2d
from fuel.datasets import MNIST
from fuel.streams import DataStream
from fuel.transformers import Mapping
from fuel.schemes import SequentialScheme
from blocks.bricks.cost import MisclassificationRate

# %% [markdown]
# #### Load models and data

# %%
model_name = 'best_varcomp.pkl'
states, causes, clf = cPickle.load(file(model_name, 'r'))

mnist = MNIST('train', sources=['features'])
data, _ = mnist._load_mnist()
means = data.mean(axis=0)

def _meanize(data):
    newfirst = data[0] - means[None, :]
    return (newfirst, data[1])

mnist_test = MNIST("test")
teststream = Mapping(DataStream(mnist_test,
                     iteration_scheme=SequentialScheme(
                         mnist_test.num_examples, 100)),
                     _meanize)

# %% [markdown]
# #### Visualize weights

# %%
rcParams['figure.figsize'] = 5,5
W = states.W.get_value()
I = grid2d(W[:100])
imshow(I, cmap='gray')

# %% [markdown]
# #### Reconstructions

# %%
X = tensor.matrix('features')
U = causes.apply(inputs=X, n_steps=100, batch_size=100)[1][-1]
Z = states.apply(inputs=X, n_steps=100, batch_size=100, gamma=U)[1][-1]
Y = tensor.dot(Z, states.W)
F = function([X], Y)
E = function([X], tensor.sqr(X-Y[-1]).sum())

total_error = 0
total_energy = 0
for x_val in teststream.get_epoch_iterator():
    total_error += E(x_val[0])
    total_energy += (x_val[0]**2).sum()

y = F(x_val[0])
rec = y[0,0,:].reshape((28,28))
imshow(rec, cmap='gray')

print "SNR (DB) = %f" % (10*np.log10(total_energy/total_error))
# Out:
# WARNING:root:unknown input sparsefilter_apply_gamma
#
# Your function uses a non-shared variable other than those given by scan explicitly. That can significantly slow down `tensor.grad` call. Did you forget to declare it in `contexts`?
# WARNING:root:unknown input sparsefilter_apply_gamma
#
# Your function uses a non-shared variable other than those given by scan explicitly. That can significantly slow down `tensor.grad` call. Did you forget to declare it in `contexts`?
# ERROR (theano.gof.opt): SeqOptimizer apply <theano.scan_module.scan_opt.PushOutSeqScan object at 0x7f7ac8bb0a50>
# ERROR:theano.gof.opt:SeqOptimizer apply <theano.scan_module.scan_opt.PushOutSeqScan object at 0x7f7ac8bb0a50>
# ERROR (theano.gof.opt): Traceback:
# ERROR:theano.gof.opt:Traceback:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/eders/python/Theano/theano/gof/opt.py", line 195, in apply
#     sub_prof = optimizer.optimize(fgraph)
#   File "/home/eders/python/Theano/theano/gof/opt.py", line 81, in optimize
#     ret = self.apply(fgraph, *args, **kwargs)
#   File "/home/eders/python/Theano/theano/scan_module/scan_opt.py", line 390, in apply
#     self.process_node(fgraph, node)
#   File "/home/eders/python/Theano/theano/scan_module/scan_opt.py", line 477, in process_node
#     new_outer = outside_ins.dimshuffle(new_ord)
#   File "/home/eders/python/Theano/theano/tensor/var.py", line 340, in dimshuffle
#     pattern)
#   File "/home/eders/python/Theano/theano/tensor/elemwise.py", line 141, in __init__
#     (i, j, len(input_broadcastable)))
# ValueError: new_order[3] is 2, but the input only has 2 axes.
# ERROR:theano.gof.opt:Traceback (most recent call last):
#   File "/home/eders/python/Theano/theano/gof/opt.py", line 195, in apply
#     sub_prof = optimizer.optimize(fgraph)
#   File "/home/eders/python/Theano/theano/gof/opt.py", line 81, in optimize
#     ret = self.apply(fgraph, *args, **kwargs)
#   File "/home/eders/python/Theano/theano/scan_module/scan_opt.py", line 390, in apply
#     self.process_node(fgraph, node)
#   File "/home/eders/python/Theano/theano/scan_module/scan_opt.py", line 477, in process_node
#     new_outer = outside_ins.dimshuffle(new_ord)
#   File "/home/eders/python/Theano/theano/tensor/var.py", line 340, in dimshuffle
#     pattern)
#   File "/home/eders/python/Theano/theano/tensor/elemwise.py", line 141, in __init__
#     (i, j, len(input_broadcastable)))
# ValueError: new_order[3] is 2, but the input only has 2 axes.
# ERROR (theano.gof.opt): SeqOptimizer apply <theano.scan_module.scan_opt.PushOutSeqScan object at 0x7f7ac8bb0a50>
# ERROR:theano.gof.opt:SeqOptimizer apply <theano.scan_module.scan_opt.PushOutSeqScan object at 0x7f7ac8bb0a50>
# ERROR (theano.gof.opt): Traceback:
# ERROR:theano.gof.opt:Traceback:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/home/eders/python/Theano/theano/gof/opt.py", line 195, in apply
#     sub_prof = optimizer.optimize(fgraph)
#   File "/home/eders/python/Theano/theano/gof/opt.py", line 81, in optimize
#     ret = self.apply(fgraph, *args, **kwargs)
#   File "/home/eders/python/Theano/theano/scan_module/scan_opt.py", line 390, in apply
#     self.process_node(fgraph, node)
#   File "/home/eders/python/Theano/theano/scan_module/scan_opt.py", line 477, in process_node
#     new_outer = outside_ins.dimshuffle(new_ord)
#   File "/home/eders/python/Theano/theano/tensor/var.py", line 340, in dimshuffle
#     pattern)
#   File "/home/eders/python/Theano/theano/tensor/elemwise.py", line 141, in __init__
#     (i, j, len(input_broadcastable)))
# ValueError: new_order[3] is 2, but the input only has 2 axes.
# ERROR:theano.gof.opt:Traceback (most recent call last):
#   File "/home/eders/python/Theano/theano/gof/opt.py", line 195, in apply
#     sub_prof = optimizer.optimize(fgraph)
#   File "/home/eders/python/Theano/theano/gof/opt.py", line 81, in optimize
#     ret = self.apply(fgraph, *args, **kwargs)
#   File "/home/eders/python/Theano/theano/scan_module/scan_opt.py", line 390, in apply
#     self.process_node(fgraph, node)
#   File "/home/eders/python/Theano/theano/scan_module/scan_opt.py", line 477, in process_node
#     new_outer = outside_ins.dimshuffle(new_ord)
#   File "/home/eders/python/Theano/theano/tensor/var.py", line 340, in dimshuffle
#     pattern)
#   File "/home/eders/python/Theano/theano/tensor/elemwise.py", line 141, in __init__
#     (i, j, len(input_broadcastable)))
# ValueError: new_order[3] is 2, but the input only has 2 axes.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-179ca524c342> in <module>()
#      13
#      14 y = F(x_val[0])
# ---> 15 rec = y[0,0,:].reshape((28,28))
#      16 imshow(rec, cmap='gray')
#      17
#
# IndexError: too many indices for array

# %% [markdown]
# #### Classification

# %%
TT = tensor.matrix('targets')
probs = clf.apply(Z)
clf_error_rate = MisclassificationRate().apply(TT.flatten(), probs)
CLF = theano.function([X,TT], clf_error_rate)

error_rate = 0
for x_val in teststream.get_epoch_iterator():
    error_rate += CLF(x_val[0], x_val[1])
    
print "total error rate = %f" % (error_rate/100)
# Out:
# total error rate = 0.358900
