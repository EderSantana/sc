# %%
# %matplotlib inline
from pylab import imshow
import cPickle
from agnez.weight import grid2d
from pylab import rcParams

# %%
rcParams['figure.figsize'] = [10,10]

# %%
M = cPickle.load(file('best_varcomp.pkl', 'r'))
A = M[0].params[0].get_value()

# %%
D = grid2d(A)
imshow(D, cmap='gray')

# %%
A.shape
# Out:
# (100, 784)
